# %%
# %load_ext autoreload
# %autoreload 2

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/moe-gpt-project
# Out:
# /content/drive/MyDrive/moe-gpt-project

# %%
# !ls
# Out:
# check_dataset.py	      moe_dispatch_combine_cuda.cu  test_model.py
# dist			      moe_ffn_cpp.cpp		    test_wikitext.py
# main.ipynb		      moe_ffn_cuda.cu		    tokenized_cache
# model_baseline.py	      moe_ffn.py		    train_baseline.py
# model_kernel.py		      out-moe			    train_moe.py
# model.py		      __pycache__		    venv
# moe_combine.py		      setit.py
# moe_dispatch_combine_cpp.cpp  setup.py

# %%
# 2. Keep tokenized data cache (don't delete this!)
# !ls -lh tokenized_cache/
# Out:
# total 8.0K
# drwx------ 2 root root 4.0K Dec 19 23:58 train_tokenized_512.pt
# drwx------ 2 root root 4.0K Dec 19 23:58 val_tokenized_512.pt

# %%
# !pip install -U datasets transformers accelerate sentencepiece huggingface_hub fsspec
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.3/512.3 kB 52.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 55.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.9/380.9 kB 58.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 108.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.1/566.1 kB 64.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.0/201.0 kB 30.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 23.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 15.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 102.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 120.9 MB/s eta 0:00:00
# ...

# %%
# !python setit.py install
#if running other kernel implementation uncomment line below and comment line above
#in addition go to drive folder of the project and change the name of model_kernel.py to model.py and change model.py to model_kernel.py
#to run the other kernel implementation
#!python setup.py install
# Out:
# running install
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
# ...

# %%
# !rm -rf build *.egg-info **/__pycache__
# !export TORCH_CUDA_ARCH_LIST="8.0"

# %%
# !rm -rf out-baseline out-moe

# !python train_moe.py
# Out:
# MegaBlocks not installed. MoE will not be available.
# ...
# MOE GPT TRAINING
# ...
# Device: cuda
# Dtype: bfloat16
# Model: 24L, 16H, 1024D (MoE: 8 experts, top_k=2)
# Batch size: 2 × 2 = 4
# Max iterations: 5000
# ...
#
# Loading dataset...
# tokenizer_config.json: 100% 26.0/26.0 [00:00<00:00, 162kB/s]
# vocab.json: 100% 1.04M/1.04M [00:00<00:00, 1.64MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 2.04MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 13.2MB/s]
# config.json: 100% 665/665 [00:00<00:00, 4.41MB/s]
# ✗ Cache not found, tokenizing dataset (this will take ~17 minutes)...
# README.md: 10.5kB [00:00, 39.8MB/s]
# wikitext-103-v1/test-00000-of-00001.parq(…): 100% 722k/722k [00:02<00:00, 264kB/s]
# wikitext-103-v1/train-00000-of-00002.par(…): 100% 156M/156M [00:04<00:00, 36.5MB/s]
# wikitext-103-v1/train-00001-of-00002.par(…): 100% 156M/156M [00:04<00:00, 32.6MB/s]
# wikitext-103-v1/validation-00000-of-0000(…): 100% 655k/655k [00:02<00:00, 301kB/s]
# ...

# %%
# Configure 5M
# !sed -i 's/n_layer = 24/n_layer = 4/g' train_moe.py
# !sed -i 's/n_head = 16/n_head = 4/g' train_moe.py
# !sed -i 's/n_embd = 1024/n_embd = 128/g' train_moe.py
# !sed -i 's/block_size = 1024/block_size = 256/g' train_moe.py
# !sed -i 's/max_seq_length = 1024/max_seq_length = 256/g' train_moe.py
# !sed -i 's/batch_size = 2/batch_size = 4/g' train_moe.py

# !rm -rf out-baseline out-moe

print("RUNNING 5M - 5000 ITERATIONS")
# !python train_moe.py
# Out:
# RUNNING 5M - 5000 ITERATIONS
# MegaBlocks not installed. MoE will not be available.
# ...
# MOE GPT TRAINING
# ...
# Device: cuda
# Dtype: bfloat16
# Model: 4L, 4H, 128D (MoE: 8 experts, top_k=2)
# Batch size: 4 × 2 = 8
# Max iterations: 5000
# ...
#
# Loading dataset...
# ✗ Cache not found, tokenizing dataset (this will take ~17 minutes)...
# Train examples: 1,801,350
# Val examples: 3,760
# Tokenizing train dataset...
# Tokenizing train: 100% 1801350/1801350 [18:19<00:00, 1638.63 examples/s]
# Tokenizing validation dataset...
# Tokenizing val: 100% 3760/3760 [00:02<00:00, 1281.49 examples/s]
# Saving tokenized dataset to cache...
# Saving the dataset (5/5 shards): 100% 1801350/1801350 [00:05<00:00, 331573.38 examples/s]
# Saving the dataset (1/1 shards): 100% 3760/3760 [00:00<00:00, 16826.86 examples/s]
# ✓ Cache saved!
# ✓ Data loaded: 450338 train batches, 940 val batches
#   Data loading time: 1120.82s
#
# Initializing model...
# number of parameters: 10.92M
#   Model initialization time: 0.38s
# ...

# %%
# Configure 40M
# !sed -i 's/n_layer = 24/n_layer = 6/g' train_moe.py
# !sed -i 's/n_head = 16/n_head = 6/g' train_moe.py
# !sed -i 's/n_embd = 1024/n_embd = 384/g' train_moe.py
# !sed -i 's/block_size = 1024/block_size = 512/g' train_moe.py
# !sed -i 's/max_seq_length = 1024/max_seq_length = 512/g' train_moe.py

# Keep 5000 iterations
# Keep batch = 4×2=8 (should fit fine)
# !sed -i 's/batch_size = 2/batch_size = 4/g' train_moe.py
# !rm -rf out-baseline out-moe

print("RUNNING 40M - 5000 ITERATIONS")
# !python train_moe.py
# Out:
# RUNNING 40M - 5000 ITERATIONS
# MegaBlocks not installed. MoE will not be available.
# ...
# MOE GPT TRAINING
# ...
# Device: cuda
# Dtype: bfloat16
# Model: 6L, 6H, 384D (MoE: 8 experts, top_k=2)
# Batch size: 4 × 2 = 8
# Max iterations: 5000
# ...
#
# Loading dataset...
# tokenizer_config.json: 100% 26.0/26.0 [00:00<00:00, 192kB/s]
# vocab.json: 100% 1.04M/1.04M [00:00<00:00, 1.61MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 1.08MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 2.10MB/s]
# config.json: 100% 665/665 [00:00<00:00, 5.08MB/s]
# ✗ Cache not found, tokenizing dataset (this will take ~17 minutes)...
# README.md: 10.5kB [00:00, 32.5MB/s]
# wikitext-103-v1/test-00000-of-00001.parq(…): 100% 722k/722k [00:02<00:00, 260kB/s]
# wikitext-103-v1/train-00000-of-00002.par(…): 100% 156M/156M [00:04<00:00, 32.4MB/s]
# wikitext-103-v1/train-00001-of-00002.par(…): 100% 156M/156M [00:05<00:00, 29.6MB/s]
# wikitext-103-v1/validation-00000-of-0000(…): 100% 655k/655k [00:01<00:00, 342kB/s]
# ...

# %%
# Configure 124M
# !sed -i 's/n_layer = 24/n_layer = 12/g' train_moe.py
# !sed -i 's/n_head = 16/n_head = 12/g' train_moe.py
# !sed -i 's/n_embd = 1024/n_embd = 768/g' train_moe.py
# !sed -i 's/block_size = 1024/block_size = 1024/g' train_moe.py
# !sed -i 's/max_seq_length = 1024/max_seq_length = 1024/g' train_moe.py
# !sed -i 's/batch_size = 2/batch_size = 4/g' train_moe.py

# !rm -rf out-baseline out-moe

print("RUNNING 124M - 5000 ITERATIONS")
# !python train_moe.py
# Out:
# RUNNING 124M - 5000 ITERATIONS
# MegaBlocks not installed. MoE will not be available.
# ...
# MOE GPT TRAINING
# ...
# Device: cuda
# Dtype: bfloat16
# Model: 12L, 12H, 768D (MoE: 8 experts, top_k=2)
# Batch size: 4 × 2 = 8
# Max iterations: 5000
# ...
#
# Loading dataset...
# tokenizer_config.json: 100% 26.0/26.0 [00:00<00:00, 182kB/s]
# vocab.json: 100% 1.04M/1.04M [00:00<00:00, 4.70MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 2.01MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 6.54MB/s]
# config.json: 100% 665/665 [00:00<00:00, 5.06MB/s]
# ✗ Cache not found, tokenizing dataset (this will take ~17 minutes)...
# README.md: 10.5kB [00:00, 38.0MB/s]
# wikitext-103-v1/test-00000-of-00001.parq(…): 100% 722k/722k [00:02<00:00, 256kB/s]
# wikitext-103-v1/train-00000-of-00002.par(…): 100% 156M/156M [00:04<00:00, 34.5MB/s]
# wikitext-103-v1/train-00001-of-00002.par(…): 100% 156M/156M [00:05<00:00, 30.3MB/s]
# wikitext-103-v1/validation-00000-of-0000(…): 100% 655k/655k [00:02<00:00, 262kB/s]
# ...
